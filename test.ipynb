# %%
import pandas as pd

# %%
df = pd.read_csv('var5.csv')
df
# Out:
#       Участники гражданского оборота       Тип операции  Сумма операции  \
# 0                          физ. лицо  получение средств         3380.98
# 1                          физ. лицо  получение средств          448.95
# 2                           юр. лицо  получение средств         3764.74
# 3                           юр. лицо  получение средств         2120.20
# 4                           юр. лицо   списание средств         4086.73
# ...                              ...                ...             ...
# 99995                       юр. лицо   списание средств         2721.11
# 99996                      физ. лицо   списание средств          714.65
# 99997                      физ. лицо  получение средств         2499.86
# 99998                       юр. лицо  получение средств         1489.64
# 99999                      физ. лицо   списание средств          840.52
#
#        Вид расчета Место оплаты           Терминал оплаты Дата оплаты  \
# ...

# %%
df1 = df.drop_duplicates()
df1
# Out:
#       Участники гражданского оборота       Тип операции  Сумма операции  \
# 0                          физ. лицо  получение средств         3380.98
# 1                          физ. лицо  получение средств          448.95
# 2                           юр. лицо  получение средств         3764.74
# 3                           юр. лицо  получение средств         2120.20
# 4                           юр. лицо   списание средств         4086.73
# ...                              ...                ...             ...
# 99995                       юр. лицо   списание средств         2721.11
# 99996                      физ. лицо   списание средств          714.65
# 99997                      физ. лицо  получение средств         2499.86
# 99998                       юр. лицо  получение средств         1489.64
# 99999                      физ. лицо   списание средств          840.52
#
#        Вид расчета Место оплаты           Терминал оплаты Дата оплаты  \
# ...

# %%
df1 = pd.read_csv('other.csv')
df1['Место оплаты'].unique()
# Out:
# array(['Брест', 'Могилев', 'Гродно', 'Витебск', 'Гомель'], dtype=object)
